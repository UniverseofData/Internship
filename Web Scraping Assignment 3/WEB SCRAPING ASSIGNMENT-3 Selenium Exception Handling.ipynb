# %% [markdown]
# >## <b> WEB SCRAPING ASSIGNMENT 3 Selenium Exception Handling </b>
#
# <b><em> By: Ms. Yashshree bawiskar </em></b>

# %% [markdown]
# <b>Q1.Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars.</b>

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time
import warnings
warnings.filterwarnings('ignore')
import requests
import re

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r'C:\chromedriver.exe') 
time.sleep(3)

# Opening the homepage of Amazon.in
url = "https://www.amazon.in/"
driver.get(url)

time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the product you want to search : ')
# Out:
# Enter the product you want to search : Guitar

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")    # Locating searc_bar by id
search_bar.clear()                                               # clearing search_bar
search_bar.send_keys(user_inp)                                   # sending user input to search bar
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')       # Locating search_button by xpath
search_button.click()

# %% [markdown]
# <b> Q.2 In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“ </b>

# %%
# scrape all product urls
product_urls = []
start=0
end=3
for page in range(start,end):#for loop for scrapping 3 page
    url=driver.find_elements_by_xpath('//a[@class="a-link-normal a-text-normal"]')       #scraping urls
    for i in url:
        product_urls.append(i.get_attribute("href"))
        #appending the urls in product_urls list
    try:
        nxt_button=driver.find_element_by_xpath("//li[@class='a-last']//a")     #scraping the list of buttons from the page
        nxt_button.click()
    except NoSuchElementException:    
        time.sleep(2)

#Make empty lists
Brand = []   
Name = []
Rating = []
no_of_ratings = []
Price = []
Return = []
expected_delivery = []
Availability = [] 
Other_Details = []

for url in product_urls:
    driver.get(url)
    time.sleep(2)
    
    # Extracting Brand from xpath
    try:
        brand = driver.find_element_by_xpath('//a[@id="bylineInfo"]')      
        Brand.append(brand.text)
    except NoSuchElementException:
        Brand.append('-')    


    time.sleep(1)
    # Extracting name from id
    try:
        name = driver.find_element_by_id('productTitle')      
        Name.append(name.text)
    except NoSuchElementException:
        Name.append('-')


    time.sleep(1)    
    # Extracting Ratings from xpath    
    try:
        rating = driver.find_element_by_xpath('//span[@class="a-size-base a-nowrap"]//span')  
        Rating.append(rating.text)
    except NoSuchElementException:
        Rating.append('-')


    time.sleep(1)
    # Extracting No of Ratings from xpath
    try:
        no_rating = driver.find_element_by_xpath('//span[@class="a-size-base a-color-secondary"]')  
        no_of_ratings.append(no_rating.text)
    except NoSuchElementException:
        no_of_ratings.append('-')


    time.sleep(1)
    # Extracting price from xpath    
    try:
        price = driver.find_element_by_xpath('//td[@class="a-span12"]')  
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('-')


    time.sleep(1)
    # Extracting Return from xpath
    try:
        return_ = driver.find_element_by_xpath('//a[@class="a-size-small a-link-normal a-text-normal"]')  
        Return.append(return_.text)
    except NoSuchElementException:
        Return.append('-')


    time.sleep(1)
    # Extracting expected_delivery from xpath
    try:
        exptd_dlvry= driver.find_element_by_xpath('//span[@class="a-color-error"]')  
        expected_delivery.append(exptd_dlvry.text)
    except NoSuchElementException:
         expected_delivery.append('-')


    time.sleep(1)
    # Extracting Availability from xpath         
    try:
        avl= driver.find_element_by_xpath('//span[@class="a-size-medium a-color-success"]')  
        Availability.append(avl.text)
    except NoSuchElementException:
        Availability.append('-')



    time.sleep(1)
    # Extracting Other Details from xpath    
    try:
        othr_dtls= driver.find_element_by_xpath('//ul[@class="a-unordered-list a-vertical a-spacing-mini"]')  
        Other_Details.append(othr_dtls.text)
    except NoSuchElementException:
        Other_Details.append('-')

time.sleep(2)    
# Make dataframe
prod_df = pd.DataFrame({'Brand':Brand,'Name':Name,'Rating':Rating,'No. of ratings':no_of_ratings,'Price':Price,
                        'Return/Exchange':Return,'Expected Delivery':expected_delivery,'Availability':Availability,
                        'Other Details':Other_Details,'URL':product_urls})
prod_df
# Out:
#                        Brand  \
# 0    Visit the Kadence Store
# 1    Visit the Kadence Store
# 2    Visit the Kadence Store
# 3    Visit the Kadence Store
# 4    Visit the Kadence Store
# ..                       ...
# 130    Visit the VAULT Store
# 131  Visit the Kadence Store
# 132  Visit the Kadence Store
# 133  Visit the Kadence Store
# 134  Visit the Kadence Store
#
#                                                   Name        Rating  \
# 0    Kadence Guitar Acoustica Series, Electric Acou...    4 out of 5
# 1    Kadence Guitar Frontier Series, Electric Acous...    4 out of 5
# 2    Kadence Guitar Frontier Series, Electric Acous...    4 out of 5
# 3    Kadence Guitar Frontier Series, Electric Acous...    4 out of 5
# 4    Kadence Guitar Frontier Series, Electric Acous...    4 out of 5
# ..                                                 ...           ...
# 130  Vault Performer Pro FX Premium Electro Acousti...             -
# 131  Kadence Acoustica Series, Semi Acoustic Guitar...  3.5 out of 5
# 132  Kadence Acoustica Series, Semi Acoustic Guitar...  3.5 out of 5
# 133  Kadence Guitar Acoustica Series, 41” Jumbo Siz...  4.3 out of 5
# 134  Kadence Guitar Acoustica Series, 41” Jumbo Siz...  4.3 out of 5
#
#            No. of ratings      Price     Return/Exchange Expected Delivery  \
# 0      927 global ratings  ₹7,499.00     Pay on Delivery
# 1    1,062 global ratings  ₹5,999.00     Pay on Delivery
# 2    1,062 global ratings  ₹5,999.00     Pay on Delivery
# 3    1,062 global ratings  ₹5,999.00     Pay on Delivery
# 4    1,062 global ratings  ₹5,999.00     Pay on Delivery
# ..                    ...        ...                 ...               ...
# 130          Total price:          -  7 Days Replacement                 -
# 131          Total price:          -     Pay on Delivery                 -
# 132          Total price:          -     Pay on Delivery                 -
# 133          Total price:  ₹7,499.00     Pay on Delivery                 -
# 134          Total price:  ₹7,499.00     Pay on Delivery                 -
#
#     Availability                                      Other Details  \
# 0                 *ACOUSTIC-ELECTRIC GUITAR: Kadence ash wood gu...
# 1                 ★ Design - The High Gloss finish, Simple head ...
# 2                 ★ Design - The High Gloss finish, Simple head ...
# 3                 ★ Design - The High Gloss finish, Simple head ...
# 4                 ★ Design - The High Gloss finish, Simple head ...
# ..           ...                                                ...
# 130    In stock.  Features: Single-Cutaway Dreadnought Body Styl...
# 131    In stock.  Fretboard material:Rosewood,Number of strings:...
# 132    In stock.  Product Type : Acoustic Guitar\nFretboard mate...
# 133    In stock.  CLASSIC DESIGN ---Elegant inlay provides a cla...
# 134    In stock.  CLASSIC DESIGN ---Elegant inlay provides a cla...
#
#                                                    URL
# 0    https://www.amazon.in/dp/B0757H5P13?pd_rd_i=B0...
# 1    https://www.amazon.in/gp/slredirect/picassoRed...
# 2    https://www.amazon.in/gp/slredirect/picassoRed...
# 3    https://www.amazon.in/gp/slredirect/picassoRed...
# 4    https://www.amazon.in/gp/slredirect/picassoRed...
# ..                                                 ...
# 130  https://www.amazon.in/gp/slredirect/picassoRed...
# 131  https://www.amazon.in/gp/slredirect/picassoRed...
# 132  https://www.amazon.in/gp/slredirect/picassoRed...
# 133  https://www.amazon.in/gp/slredirect/picassoRed...
# 134  https://www.amazon.in/gp/slredirect/picassoRed...
#
# [135 rows x 10 columns]

# %% [markdown]
# **Q3-Write a python program to access the search bar and search button on images.google.com and
# scrape 100 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’.**

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r'C:\chromedriver.exe') 
time.sleep(3)

# Opening the google images
url = "https://images.google.com/"
driver.get(url)


search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("fruits")       # Inputing "fruits" keyword to search images
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Finding the xpath of search button
search_button.click()        # Clicking the search button


# 500 time we scroll down by 10000 in order to generate more images on the website
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")
    
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"D:\Fliprobo data\fliprobo images\Fruit"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r'C:\chromedriver.exe') 
time.sleep(3)

# Opening the google images
url = "https://images.google.com/"
driver.get(url)


search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("cars")       # Inputing "cars" keyword to search images
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Finding the xpath of search button
search_button.click()        # Clicking the search button


# 500 time we scroll down by 10000 in order to generate more images on the website
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")
    
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"D:\Fliprobo data\fliprobo images\Cars"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %%
# Activating the chrome browser
driver=webdriver.Chrome(r'C:\chromedriver.exe') 
time.sleep(3)

# Opening the google images
url = "https://images.google.com/"
driver.get(url)


search_bar = driver.find_element_by_xpath('//*[@id="sbtc"]/div/div[2]/input')    # Finding the search bar using it's xpath
search_bar.send_keys("Machine Learning")       # Inputing "Machine Learning" keyword to search images
search_button = driver.find_element_by_xpath('//*[@id="sbtc"]/button')    # Finding the xpath of search button
search_button.click()        # Clicking the search button


# 500 time we scroll down by 10000 in order to generate more images on the website
for _ in range(500):
    driver.execute_script("window.scrollBy(0,10000)")
    
images = driver.find_elements_by_xpath('//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
            
for i in range(len(img_urls)):
    if i >= 100:
        break
    print("Downloading {0} of {1} images" .format(i, 100))
    response= requests.get(img_urls[i])
    file = open(r"D:\Fliprobo data\fliprobo images\Machine Learning"+str(i)+".jpg", "wb")
    file.write(response.content)
# Out:
# Downloading 0 of 100 images
# Downloading 1 of 100 images
# Downloading 2 of 100 images
# Downloading 3 of 100 images
# Downloading 4 of 100 images
# Downloading 5 of 100 images
# Downloading 6 of 100 images
# Downloading 7 of 100 images
# Downloading 8 of 100 images
# Downloading 9 of 100 images
# Downloading 10 of 100 images
# Downloading 11 of 100 images
# Downloading 12 of 100 images
# Downloading 13 of 100 images
# Downloading 14 of 100 images
# Downloading 15 of 100 images
# Downloading 16 of 100 images
# Downloading 17 of 100 images
# Downloading 18 of 100 images
# Downloading 19 of 100 images
# Downloading 20 of 100 images
# Downloading 21 of 100 images
# Downloading 22 of 100 images
# Downloading 23 of 100 images
# Downloading 24 of 100 images
# Downloading 25 of 100 images
# Downloading 26 of 100 images
# Downloading 27 of 100 images
# Downloading 28 of 100 images
# Downloading 29 of 100 images
# Downloading 30 of 100 images
# Downloading 31 of 100 images
# Downloading 32 of 100 images
# Downloading 33 of 100 images
# Downloading 34 of 100 images
# Downloading 35 of 100 images
# Downloading 36 of 100 images
# Downloading 37 of 100 images
# Downloading 38 of 100 images
# Downloading 39 of 100 images
# Downloading 40 of 100 images
# Downloading 41 of 100 images
# Downloading 42 of 100 images
# Downloading 43 of 100 images
# Downloading 44 of 100 images
# Downloading 45 of 100 images
# Downloading 46 of 100 images
# Downloading 47 of 100 images
# Downloading 48 of 100 images
# Downloading 49 of 100 images
# Downloading 50 of 100 images
# Downloading 51 of 100 images
# Downloading 52 of 100 images
# Downloading 53 of 100 images
# Downloading 54 of 100 images
# Downloading 55 of 100 images
# Downloading 56 of 100 images
# Downloading 57 of 100 images
# Downloading 58 of 100 images
# Downloading 59 of 100 images
# Downloading 60 of 100 images
# Downloading 61 of 100 images
# Downloading 62 of 100 images
# Downloading 63 of 100 images
# Downloading 64 of 100 images
# Downloading 65 of 100 images
# Downloading 66 of 100 images
# Downloading 67 of 100 images
# Downloading 68 of 100 images
# Downloading 69 of 100 images
# Downloading 70 of 100 images
# Downloading 71 of 100 images
# Downloading 72 of 100 images
# Downloading 73 of 100 images
# Downloading 74 of 100 images
# Downloading 75 of 100 images
# Downloading 76 of 100 images
# Downloading 77 of 100 images
# Downloading 78 of 100 images
# Downloading 79 of 100 images
# Downloading 80 of 100 images
# Downloading 81 of 100 images
# Downloading 82 of 100 images
# Downloading 83 of 100 images
# Downloading 84 of 100 images
# Downloading 85 of 100 images
# Downloading 86 of 100 images
# Downloading 87 of 100 images
# Downloading 88 of 100 images
# Downloading 89 of 100 images
# Downloading 90 of 100 images
# Downloading 91 of 100 images
# Downloading 92 of 100 images
# Downloading 93 of 100 images
# Downloading 94 of 100 images
# Downloading 95 of 100 images
# Downloading 96 of 100 images
# Downloading 97 of 100 images
# Downloading 98 of 100 images
# Downloading 99 of 100 images

# %% [markdown]
# **Q4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Display Resolution”, “Processor”, “Processor Cores”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.**

# %%
# Importing require libary
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# Opening url in Chrome browser
url='http://www.flipkart.com/'
driver.get(url)
time.sleep(3)

try:
    login_window = driver.find_element_by_xpath('//button[@class="_2KpZ6l _2doB4z"]')
    login_window.click()
except NoSuchElementException:
    print('Login Window is not present')

# %%
# Finding Search bar website by xpath
Search=driver.find_element_by_xpath('//div[@class="_3OO5Xc"]/input')
# Clearing any previous input in search bar
Search.clear()
# Feeding input 'Oneplus' in search bar
Search.send_keys('Iphone Mobile')
# Finding Search button for clicking through class name
Search_button=driver.find_element_by_xpath('//button[@class="L0Z3Pu"]')
# Clicking search button
Search_button.click()

# %%
# Making empty list to scrape data
Brand =[]
Smartphone =[]
Colour =[]
Storage_Rom =[]
Primary_camera=[]
Secondary_camera=[]
Display_size=[]
Display_resolution=[]
Processor =[]
Processor_cores=[]
Battery_capacity=[]
Price =[]

# %%
URL=[]
url=driver.find_elements_by_xpath('//a[@class="_1fQZEK"]')
for i in url:
    Href=i.get_attribute('href')
    URL.append(Href)

# %%
len(URL)
# Out:
# 24

# %%
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    time.sleep(3)
    
    # Expanding specification table by clicking on read more button
    try:
        Read_more=driver.find_element_by_xpath('//button[@class="_2KpZ6l _1FH0tX"]')
        Read_more.click()
        
    except NoSuchElementException:
        print('NoSuchElementException Occur')
        pass
    
    # Extracting Brand Name via Xpath
    try:
        brand=driver.find_element_by_xpath('//span[@class="B_NuCI"]')
        Brand.append(brand.text.split()[0])
    
    except NoSuchElementException:
        Brand.append('-')
        
    # Extracting Smartphone Model via Xpath
    try:
        smartphone=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        Smartphone.append(smartphone.text)
    
    except NoSuchElementException:
        Smartphone.append('-')
        
    # Extracting Colour via Xpath
    try:
        colour=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(colour.text)
    
    except NoSuchElementException:
        Colour.append('-')
    
    # Extracting Storage Rom via Xpath
    try:
        Rom=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        Storage_Rom.append(Rom.text)
        
    except NoSuchElementException:
        Storage_Rom.append('Not Mention')
        
    # Extracting primary camera detail via Xpath
    try:
        primary_camera=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        Primary_camera.append(primary_camera.text)
    
    except NoSuchElementException:
        Primary_camera.append('Not Mention')
        
    # Extracting Secondary Camera detail via Xpath
    try:
        secondary_cam=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][5]/table/tbody/tr[5]/td[2]/ul/li')
        Secondary_camera.append(secondary_cam.text)
    
    except NoSuchElementException:
        Secondary_camera.append('Not Mention')
    
    # Extracting Display size via Xpath
    try:
        display=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        Display_size.append(display.text)
    except NoSuchElementException:
        Display_size.append('-')
    
    # Extracting Display Resolution via Xpath
    try:
        resolution=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][2]/table/tbody/tr[2]/td[2]/ul/li')
        Display_resolution.append(resolution.text)
    except NoSuchElementException:
        Display_resolution.append('-')
    
    # Extracting processor detail via xpath
    try:
        processor=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table/tbody/tr[2]/td[2]/ul/li')
        Processor.append(processor.text)
    
    except NoSuchElementException:
        Processor.append('-')
        
    # Extracting Processor core via xpath
    try:
        core=driver.find_element_by_xpath('//div[@class="_3k-BhJ"][3]/table/tbody/tr[3]/td[2]/ul/li')
        Processor_cores.append(core.text)
    except NoSuchElementException:
        Processor_cores.append('Not Mention')
    
    #Extracting Price via X path
    try:
        price=driver.find_element_by_xpath('//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('Not Mention')
# Out:
# 100%|██████████| 24/24 [02:52<00:00,  7.19s/it]

# %%
Iphone=pd.DataFrame({'Brand':Brand,'Smartphone':Smartphone,'Colour':Colour,'Price':Price,
                        'Storage Rom':Storage_Rom,'Primary Camera':Primary_camera,'Display Size':Display_size,
                        'Display Resolution':Display_resolution,'Processor':Processor,'Processor Cores':Processor_cores})
print('\033[1m'+'Flipkart Iphone Models :'+'\033[0m')
Iphone.head()
# Out:
# Flipkart Iphone Models :
#    Brand      Smartphone    Colour    Price Storage Rom Primary Camera  \
# 0  APPLE               -         -  ₹27,999    iOS 14.2    Not Mention
# 1  APPLE       iPhone 13     Green  ₹74,900      128 GB    12MP + 12MP
# 2  APPLE       iPhone 13  Midnight  ₹74,900      128 GB    12MP + 12MP
# 3  APPLE  iPhone 13 Mini  Midnight  ₹59,999      128 GB    12MP + 12MP
# 4  APPLE  iPhone 13 Mini      Pink  ₹59,999      128 GB    12MP + 12MP
#
#                                       Display Size  Display Resolution  \
# 0  iPhone, USB-C to Lightning Cable, Documentation           MHGV3HN/A
# 1                              15.49 cm (6.1 inch)  2532 x 1170 Pixels
# 2                              15.49 cm (6.1 inch)  2532 x 1170 Pixels
# 3                              13.72 cm (5.4 inch)  2340 x 1080 Pixels
# 4                              13.72 cm (5.4 inch)  2340 x 1080 Pixels
#
#            Processor    Processor Cores
# 0  1334 x 750 Pixels  Retina HD Display
# 1    A15 Bionic Chip          Hexa Core
# 2    A15 Bionic Chip          Hexa Core
# 3    A15 Bionic Chip          Hexa Core
# 4    A15 Bionic Chip          Hexa Core

# %% [markdown]
# **Q5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.**

# %%
import selenium
import pandas as pd
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# Opening url in chrome browser
url='https://www.google.co.in/maps'
driver.get(url)
time.sleep(3)

# %%
# Finding search menu by xpath
Search=driver.find_element_by_id("searchboxinput") 
# clearing any previous input in search bar
Search.clear()
# Feeding input specified by user to search menu through send keys
Search.send_keys('Nashik')
# Finding Search button for clicking through xpath
Search_button=driver.find_element_by_id("searchbox-searchbutton")  
# Clicking search button
Search_button.click()

# %%
current_url=driver.current_url
print('Current url :',current_url)
# Out:
# Current url : https://www.google.co.in/maps/place/Nashik,+Maharashtra/@19.9912307,73.6633907,11z/data=!3m1!4b1!4m5!3m4!1s0x3bddd290b09914b3:0xcb07845d9d28215c!8m2!3d19.9974533!4d73.7898023

# %%
try:
    if "@" in current_url:
        location=current_url.split('@')[1].split(',*/data')[0].split(',')
        location
        print('Latitude of given Location:',location[0])
        print('Longitude of given Location:',location[1])
except:
    print('Location detail not found in url')
# Out:
# Latitude of given Location: 19.9912307
# Longitude of given Location: 73.6633907

# %% [markdown]
# **Q6. Write a program to scrap details of all the funding deals for second quarter (i.e. July 20 –September 20) from trak.in.**

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# Opening url in chrome browser
url='https://www.trak.in'
driver.get(url)
time.sleep(3)

# %%
# Clicking funding deals button
Funding_deals=driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(Funding_deals)

# %%
# Making Empty list to scrap data
Date=[]
Startup=[]
Industry=[]
Sub_vertical=[]
City=[]
Investor=[]
Investment_type=[]
Amount=[]

# %%
from tqdm import tqdm
for i in tqdm(range(53,57)):
    # Extracting Date from table
    try:
        date=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
        for j in date:
            Date.append(j.text)
    except:
        Date.append('NA')
        
    # Extracting startup name via xpath
    try:
        startup=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
        for j in startup:
            Startup.append(j.text)
    except:
        Startup.append('NA')
    
    # Extracting Industry vertical via Xpath
    try:
        industry=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
        for j in industry:
            Industry.append(j.text)
    except:
        Industry.append('NA')
    
    # Extracting subvertical via xpath
    try:
        subvertical=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
        for j in subvertical:
            Sub_vertical.append(j.text)
    except:
        Sub_vertical.append('NA')
    
    # Extracting city/location via xpath
    try:
        city=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
        for j in city:
            City.append(j.text)
    except:
        City.append('NA')
        
    # Extracting Investor via xpath
    try:
        investor=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
        for j in investor:
            Investor.append(j.text)
    except:
        Investor.append('NA')
        
    # Extracting Investment type via xpath
    try:
        investment_type=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
        for j in investment_type:
            Investment_type.append(j.text)
    except:
        Investment_type.append('NA')
        
    # Extracting Amount type via xpath
    try:
        amount=driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
        for j in amount:
            Amount.append(j.text)
    except:
        Amount.append('NA')
# Out:
# 100%|██████████| 4/4 [00:18<00:00,  4.68s/it]

# %%
Funding=pd.DataFrame({'Date':Date,'Startup Company':Startup,'Industry/Vertical':Industry,'Sub-Vertical':Sub_vertical,'City':City,
                        'Investor':Investor,'Investment Type':Investment_type,'Amount':Amount})
print('\033[1m'+'Funding deals in second quarter (i.e. January 2021 –March 2021) :'+'\033[0m')
Funding
# Out:
# Funding deals in second quarter (i.e. January 2021 –March 2021) :
#           Date         Startup Company       Industry/Vertical  \
# 0   15/12/2020                 Bira 91       Food and Beverage
# 1   21/12/2020               Pine Labs      Financial Services
# 2   15/12/2020                  Zenoti     Technology Provider
# 3   22/12/2020         Tax Buddy India                 FinTech
# 4   15/12/2020               Delhivery            Supply chain
# 5   18/12/2020               PagarBook                    SaaS
# 6   15/01/2021         Digit Insurance      Financial Services
# 7   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 8   19/01/2021                  DeHaat        AgriTech Startup
# 9   19/01/2021               Darwinbox                    SaaS
# 10  18/01/2021                   mfine     Health Tech Startup
# 11  18/01/2021                   Udayy                  EdTech
# 12  11/01/2021           True Elements            Food Startup
# 13  13/01/2021                   Saveo          B2B E-commerce
# 14  11/02/2021                Doubtnut                Edu Tech
# 15  22/02/2021                  Zomato             Hospitality
# 16  19/02/2021               Fingerlix             Hospitality
# 17  17/02/2021                   Zolve                 FinTech
# 18  15/02/2021               KreditBee                 Finance
# 19  12/02/2021               Pepperfry              E-commerce
# 20  12/02/2021                 Grofers              E-Commerce
# 21  09/02/2021                 Nothing              Technology
# 22  09/02/2021             SplashLearn                  EdTech
# 23  04/03/2021               DealShare              E-commerce
# 24  31/03/2021                Uniphore              Technology
# 25  30/03/2021                   Dunzo              E-commerce
# 26  30/03/2021                  BYJU’S                Edu-tech
# 27  23/03/2021             SkilloVilla                Edu-tech
# 28  25/03/2021                CityMall              E-commerce
# 29  26/03/2021                   DotPe                 FinTech
#
#                                          Sub-Vertical               City  \
# 0                                          Craft Beer          New Delhi
# 1                          Payment Solutions Provider              Noida
# 2   Cloud-based software provider for the spa and ...         Washington
# 3                                  Online tax adviser             Mumbai
# 4                                      Transportation            Gurgaon
# 5                        Employee management platform          Bengaluru
# 6                                  Insurance Services          Bengaluru
# 7       Shave care, beard care, and skincare products          New Delhi
# 8   online marketplace for farm products and services              Patna
# 9                                             HR Tech             Mumbai
# 10                 AI-powered telemedicine mobile app          Bengaluru
# 11     Online learning platform for kids in class 1-5            Gurgaon
# 12                      Whole Food plant based Nashta               Pune
# 13                                         Pharmacies          Bengaluru
# 14                                E-Learning Platform            Gurgaon
# 15                      Online Food Delivery Platform            Gurgaon
# 16                      Semi-cooked food delivery app             Mumbai
# 17                             Global Neobank Venture             Mumbai
# 18                           Digital lending platform          Bengaluru
# 19                        Multi-brand furniture brand             Mumbai
# 20                                 Online supermarket            Gurgaon
# 21                        Consumer Technology Venture             London
# 22                      Game-based learning programme            Gurgaon
# 23                           Online shopping platform  Jaipur, Rajasthan
# 24            Conversational Service Automation (CSA)          Palo Alto
# 25                           Hyper-local delivery app          Bengaluru
# 26                                    Online tutoring          Bengaluru
# 27                Career and job-oriented upskilling.          Bengaluru
# 28       Social ecommerce and online grocery platform            Gurgaon
# 29  Commerce and payments platform to offline ente...            Gurgaon
#
#                                              Investor   Investment Type  \
# 0   Nishant Mittal, Pankaj Chaddah and Shikha Suni...           Funding
# 1                                   Lone Pine Capital  Secondary Market
# 2                                Advent International          Series D
# 3                                       Zenith Global              Seed
# 4                                   Steadview Capital  Secondary Market
# 5                                     Sequoia Capital          Series A
# 6    A91 Partners, Faering Capital, TVS Capital Funds           Venture
# 7                                   Reckitt Benckiser           Venture
# 8                                     Prosus Ventures          Series C
# 9                                 Salesforce Ventures              Seed
# 10                         Heritas Capital Management     Venture Round
# 11                                    Sequoia Capital      Seed Funding
# 12                              SIDBI Venture Capital            Series
# 13          Matrix Partners India, RTP Global, others              Seed
# 14  SIG Global, Sequoia Capital, WaterBridge Ventu...          Series B
# 15                                 Tiger Global, Kora           Venture
# 16           Rhodium Trust, Accel Partners and Swiggy          Series C
# 17     Accel Partners and Lightspeed Venture Partners              Seed
# 18  Azim Premji’s PremjiInvest and South Korea’s M...          Series C
# 19                                    InnoVen Capital    Debt Financing
# 20                         SoftBank Vision Fund (SVF)       Unspecified
# 21                                                 GV          Series A
# 22                                       Owl Ventures          Series C
# 23                                    Innoven Capital    Debt Financing
# 24                          Sorenson Capital Partners          Series D
# 25                          Krishtal Advisors Pte Ltd          Series E
# 26         MC Global Edtech, B Capital, Baron, others          Series F
# 27                              Titan Capital, others              Seed
# 28                                     Accel Partners          Series A
# 29                                               PayU          Series A
#
#           Amount
# 0   1,273,634.07
# 1    Undisclosed
# 2    160,000,000
# 3      1,000,000
# 4     25,000,000
# 5     15,000,000
# 6    1,80,00,000
# 7   6,172,258.50
# 8     30,000,000
# 9     15,000,000
# 10    16,000,000
# 11    15,000,000
# 12   100,000,000
# 13     4,000,000
# 14     2,500,000
# 15   250,000,000
# 16  2,747,045.20
# 17   1,50,00,000
# 18    75,000,000
# 19     4,773,958
# 20    55,000,000
# 21    15,000,000
# 22    18,000,000
# 23   250,000,000
# 24   140,000,000
# 25     8,000,000
# 26   460,000,000
# 27   300,000,000
# 28    11,000,000
# 29    27,500,000

# %% [markdown]
# **Q7.Write a program to scrap all the available details of best gaming laptops from digit.in.**

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# Opening url in chrome browser
url='https://www.digit.in'
driver.get(url)
time.sleep(3)

# %%
# Clicking on top 10 option button in menu bar
driver.find_element_by_xpath('//div[@class="menu"]/ul/li[4]/a').click()
time.sleep(3)

# Clicking on Laptop under table
driver.find_element_by_xpath('//div[@class="categoty_list"]/button[2]').click()

# Opening Best gaming laptops link
Gaming_lappy=driver.find_element_by_xpath('//div[@id="laptops"]/div[3]/a').get_attribute('href')
driver.get(Gaming_lappy)
time.sleep(3)

# %%
# Making Empty list for scraping data
Laptop_model =[]
OS =[]
Display = []
Processor =[]
Memory =[]
Weight =[]
Dimension =[]
Graphics_processor =[]
Price =[]

# %%
# Extracting Laptop model via Xpath
for i in range(0,11):
    laptop_model=driver.find_elements_by_xpath('//*[@id="toptenIdevent{}"]/a/h3'.format(i))
    for j in laptop_model:
        Laptop_model.append(j.text)

# %%
# Extracting OS on Laptop model via Xpath
os=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[3]/td[3]')
for j in os:
    OS.append(j.text)

# %%
# Extracting Display vertical via Xpath
display=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[4]/td[3]')
for j in display:
    Display.append(j.text)

# %%
# Extracting Processor via xpath
processor=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[5]/td[3]')
for j in processor:
    Processor.append(j.text)

# %%
# Extracting Memory via xpath
memory=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[6]/td[3]')
for j in memory:
    Memory.append(j.text)

# %%
# Extracting Laptop Weight via xpath
weight=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[7]/td[3]')
for j in weight:
    Weight.append(j.text)

# %%
# Extracting Dimension via xpath
dimension=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[8]/td[3]')
for j in dimension:
    Dimension.append(j.text)

# %%
# Extracting Graphics Processor type via xpath
graphics_processor=driver.find_elements_by_xpath('//div[@class="Spcs-details"]/table/tbody/tr[9]/td[3]')
for j in graphics_processor:
    Graphics_processor.append(j.text)

# %%
# Extracting Laptop Price type via xpath
price=driver.find_elements_by_xpath('//table[@id="summtable"]//tr//td[3]')
for j in price:
    Price.append(j.text)

# %%
#Make data frame
Gaming_Laptops=pd.DataFrame({"Laptop Model":Laptop_model,"Price":Price, "OS":OS,"Display":Display,"Memory":Memory,"Processor":Processor,
                 "Weight":Weight,"Dimension":Dimension,"Graphical processor":Graphics_processor})
print('\033[1m'+'Best Gaming Laptop :'+'\033[0m')
Gaming_Laptops
# Out:
# Best Gaming Laptop :
#                   Laptop Model      Price               OS  \
# 0                 HP VICTUS 16  ₹ 104,990       Windows 10
# 1                   HP OMEN 15  ₹ 110,790  Windows 10 Home
# 2                 ACER NITRO 5  ₹ 129,990       Windows 10
# 3              MSI STEALTH 15M  ₹ 134,990       Windows 10
# 4       ASUS ROG STRIX SCAR 15  ₹ 193,990       Windows 10
# 5       ASUS ROG STRIX SCAR 15  ₹ 215,990  Windows 10 Home
# 6            ASUS ZEPHYRUS G14  ₹ 144,990  Windows 10 Home
# 7             LENOVO LEGION 5I   ₹ 76,988   Windows 10 Pro
# 8     ASUS ROG ZEPHYRUS DUO 15  ₹ 185,000       Windows 10
# 9  ACER ASPIRE 7 GAMING LAPTOP   ₹ 53,490  Windows 10 Home
#
#                Display                   Memory  \
# 0  16.1" (1920 x 1200)  512 GB SSD/16 GBGB DDR4
# 1  15.6" (1920 x 1080)    1 TB SSD/16 GBGB DDR4
# 2  15.6" (1920 x 1080)    1 TB HDD/16 GBGB DDR4
# 3  15.6" (1920 x 1080)    1 TB SSD/16 GBGB DDR4
# 4  15.6" (2560 x 1440)    2 TB SSD/32 GBGB DDR4
# 5  15.6" (1920 x 1080)    1 TB SSD/16 GBGB DDR4
# 6    14" (1920 x 1080)    1 TB SSD/16 GBGB DDR4
# 7  15.6" (1920 x 1080)    1 TB SSD/16 GBGB DDR4
# 8  15.6" (3840 x 1100)   512 GB SSD/4 GBGB DDR4
# 9  15.6" (1920 x 1080)   512 GB SSD/8 GBGB DDR4
#
#                                     Processor Weight                Dimension  \
# 0          5th Gen AMD Ryzen 7 5800H | 3.2GHz   2.48          37 x 26.2 x 2.4
# 1       AMD Ryzen 7 Octa Core-5800H | 4.4 GHz   2.37     357.9 x 239.7 x 22.5
# 2             AMD Ryzen 9 Octa Core | 2.4 GHz    2.4       363.4 x 255 x 23.9
# 3        Intel Core i7 11th Gen - 11375H | NA    1.7      358.3 x 248 x 16.15
# 4    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz   2.30         354 x 259 x 22.6
# 5               AMD Ryzen™ 9 5900HX | 3.3 GHz   2.30       35.4 x 25.9 x 2.26
# 6               AMD 3rd Gen Ryzen 9 | 3.3 GHz   1.65        32.5 x 22.1 x 1.8
# 7  10th Gen Intel® Core™ i5-10300H | 2.50 GHz    2.3  363.06 x 259.61 x 23.57
# 8          Intel Core i7 10th Gen 10875H | NA    2.4  268.30 x 360.00 x 20.90
# 9           AMD Ryzen™ 5-5500U hexa-core | NA   2.15       2.29 x 36.3 x 25.4
#
#              Graphical processor
# 0        NVIDIA GeForce RTX 3060
# 1        NVIDIA GeForce RTX 3060
# 2        NVIDIA GeForce RTX 3070
# 3        NVIDIA GeForce RTX 3060
# 4        NVIDIA GeForce RTX 3080
# 5      NVIDIA® GeForce RTX™ 3070
# 6        NVIDIA GeForce RTX 2060
# 7  NVIDIA® GeForce® GTX 1650 4GB
# 8  NVIDIA GeForce RTX 2070 Max-Q
# 9      NVIDIA® GeForce® GTX 1650

# %% [markdown]
# **8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”**

# %%
# Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# Opening url in chrome browser
url="https://www.forbes.com"
driver.get(url)
time.sleep(1)

# %%
# Clicking on explore button to expand menu
driver.find_element_by_xpath('//button[@class="icon--hamburger"]').click()

# Clicking on Billionaire category
driver.find_element_by_xpath('//ul[@class="header__channels"]/li[1]').click()

# Clicking on world billionaire tab
driver.find_element_by_xpath('//ul[@class="header__channels"]/li[1]/div[2]/ul/li[2]/a').click()

# %%
# Empty list to scrap data
Rank =[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

# %%
  
# Extacting name
name=driver.find_elements_by_xpath('//div[@class="personName"]/div')
for i in name:
    Name.append(i.text)

#Extracting Net worth
net=driver.find_elements_by_xpath('//div[@class="netWorth"]/div')
for i in net:
    Net_worth.append(i.text)
    
# Extracting Age
age=driver.find_elements_by_xpath('//div[@class="age"]/div')
for i in age:
    Age.append(i.text)

# Extracting Citizenship
citizen=driver.find_elements_by_xpath('//div[@class="countryOfCitizenship"]')
for i in citizen:
    Citizenship.append(i.text)
    
# Extracting Source
try:
    source=driver.find_elements_by_xpath('//div[@class="source-column"]')
    for i in source:
        Source.append(i.text)
except:
    source=driver.find_elements_by_xpath('//*[@id="jeff-bezos"]/div[6]/div/div[1]')
    Source.append(i.text)
    
# Extracting Industry
industry=driver.find_elements_by_xpath("//div[@class='category']//div")
for i in industry:
    Industry.append(i.text)

# %%
# Extracting Rank No
rank=driver.find_elements_by_xpath('//div[@class="rank"]')
for i in rank:
    Rank.append(i.text)

# %%
#creating dataframe
Forbes_list=pd.DataFrame({'Rank':Rank,'Name':Name,'Net Worth':Net_worth,'Age':Age,'Citizenship':Citizenship,
                'Source':Source,'Industry':Industry})
print('\033[1m'+' Forbes World Billionaires List Oct 2021 :'+'\033[0m')
Forbes_list
# Out:
#  Forbes World Billionaires List Oct 2021 :
#      Rank                      Name Net Worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B  57  United States
# 1      2.                 Elon Musk    $151 B  49  United States
# 2      3.  Bernard Arnault & family    $150 B  72         France
# 3      4.                Bill Gates    $124 B  65  United States
# 4      5.           Mark Zuckerberg     $97 B  36  United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B  88      Australia
# 196  197.              Leonid Fedun   $11.1 B  65         Russia
# 197  197.                 Eyal Ofer   $11.1 B  70         Israel
# 198  197.              Evan Spiegel   $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento     $11 B  88       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %% [markdown]
# **Q9.Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted
# from any YouTube Video.**

# %%
#Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# Opening url in chrome browser
url="https://www.youtube.com"
driver.get(url)
time.sleep(3)

# %%
# Finding search menu by xpath
Search=driver.find_element_by_xpath('//input[@id="search"]') 
# Feeding input video name by user to search menu through send keys
Search.send_keys('Anaadi Ananta || Kailash Kher || Spiritual Nirgun || Dr.M || Mahadev || Shiv || Mystical')
# Finding Search button for clicking through xpath
Search_button=driver.find_element_by_xpath('//button[@id="search-icon-legacy"]/yt-icon')  
# Clicking search button
Search_button.click()
time.sleep(2)

# %%
# Clicking on video
link = driver.find_element_by_xpath("//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link.click()
time.sleep(3)

# %%
# Scrolling window using ScrollBy method from 0 pixel to 15000 pixel
driver.execute_script("window.scrollBy(0,1000000)","")

# %%
# Empty lists to scrap data
Comments = []
Comment_posted_ago = []
Timeline = []
Likes = []
No_of_Likes = []

# %%
#extracting comment on video
comment = driver.find_elements_by_id("content-text")
time.sleep(3)
from tqdm import tqdm
for i in tqdm(comment):
    if i.text is None:
        Comments.append("--")
    else:
        Comments.append(i.text)
time.sleep(2)
# Out:
# 100%|██████████| 600/600 [00:26<00:00, 22.42it/s]

# %%
# Extracting time of commenting
timeline = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
time.sleep(3)
from tqdm import tqdm
for i in tqdm(timeline):
    if i.text is None:
        Timeline.append("-")
    else:
        Timeline.append(i.text)
for i in tqdm(range(0,len(Timeline),2)):
    Comment_posted_ago.append(Timeline[i])
# Out:
# 100%|██████████| 1200/1200 [00:51<00:00, 23.40it/s]
# 100%|██████████| 600/600 [00:00<?, ?it/s]

# %%
# scrape the comment likes
like = driver.find_elements_by_xpath("//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])
time.sleep(3)

# %%
len(Comments),len(Comment_posted_ago),len(No_of_Likes)
# Out:
# (600, 600, 600)

# %%
YT=pd.DataFrame({})
YT['Comments']=Comments[:500]
YT['Comment Posted Ago']=Comment_posted_ago[:500]
YT['No. of Likes']=No_of_Likes[:500]
YT
# Out:
#                                               Comments Comment Posted Ago  \
# 0    एकमात्र योद्धा जो अपनी वाणी से पाश्चात्य संस्क...         1 year ago
# 1    वाह! क्या बात है...आदि शंकराचार्य के निर्वाण ष...       5 months ago
# 2    साकार और निराकार का केंद्रबिंदु शिव ही है और क...       7 months ago
# 3    इससे उत्कृष्ट आध्यात्मिक गीत आज तक मैंने नहीं ...       3 months ago
# 4    मै निशब्द हूं... बहुत ही सुंदर स्तुति.. कैलाश ...       5 months ago
# ..                                                 ...                ...
# 495                                        वाह वाह 💕💕💕        3 weeks ago
# 496                      Nice pure prayers for adiyogi       3 months ago
# 497                                  Jai bhole nath🙏🙏🙏          1 day ago
# 498  Your voice is out of this world. Really divine...         1 year ago
# 499  Good translation of Adiguru Shankaryacharya's ...        3 weeks ago
#
#     No. of Likes
# 0           3.3K
# 1            420
# 2            378
# 3            115
# 4            182
# ..           ...
# 495
# 496            1
# 497
# 498            7
# 499
#
# [500 rows x 3 columns]

# %% [markdown]
# **Q10.Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description**

# %%
#Connecting to webdriver
driver=webdriver.Chrome(r'C:/chromedriver.exe')
time.sleep(1)

# %%
# Opening url in chrome browser
url="https://www.hostelworld.com/s?q=London,%20England&country=England&city=London&type=city&id=3&from=2022-03-31&to=2022-04-03&guests=2&page=1"
driver.get(url)
time.sleep(2)

# %%
hostel=[]
dist=[]
rating=[]
overallrev=[]

# %%
#scrapping hostel names 

hostel_name=driver.find_elements_by_xpath('//div[@class="property-card"]/div[2]/a[1]/div[1]/h2')
for i in hostel_name:
    hostel.append(i.text)
hostels=driver.find_elements_by_xpath('//h2[@class="title title-6"]/a')
for i in hostels:
    hostel.append(i.text)

# %%
# scrapping distance from city centre
distance=driver.find_elements_by_xpath('//div[@class="subtitle body-3"]')
for i in distance:
    dist.append(i.text)

# %%
#scrapping ratings

ratings=driver.find_elements_by_xpath('//div[@class="score orange small"]')
for i in ratings:
    rating.append(i.text)
try:
    other_ratings=driver.find_elements_by_xpath('//div[@class="rating rating-summary-container big"]/div[1]')
    for i in other_ratings:
        rating.append(i.text)
except:
    rating.append('_')

# %%
#scrapping Overall reviews

overall_reviews=driver.find_elements_by_xpath('//div[@class="keyword"]')
for i in overall_reviews:
    overallrev.append(i.text)

# %%
hostels=pd.DataFrame({})
hostels['Name']=hostel
hostels['Distance']=dist
hostels['Ratings']=rating
hostels['Overall Reviews']=overallrev
hostels
# Out:
#                                        Name  \
# 0                  St Christopher's Village
# 1                  St Christopher's Village
# 2         Safestay London Elephant & Castle
# 3                          Generator London
# 4                      Urbany Hostel London
# 5                   Smart Camden Inn Hostel
# 6                        London Backpackers
# 7               Smart Russell Square Hostel
# 8                  YHA London Oxford Street
# 9   Safestay London Kensington Holland Park
# 10              Smart Hyde Park View Hostel
# 11     St Christopher's Inn - London Bridge
# 12                  Queen Elizabeth Chelsea
# 13              Wombat's City Hostel London
# 14                           Phoenix Hostel
# 15                     New Cross Inn Hostel
# 16               Smart Hyde Park Inn Hostel
# 17             St Christopher's Hammersmith
# 18                  St Christopher's Camden
# 19                       YHA London Central
# 20          St Christopher's Shepherds Bush
# 21                  Hostel One Notting Hill
# 22               St Christopher's Greenwich
# 23                            Selina Camden
# 24                           Abercorn House
# 25                        Hootananny Hostel
# 26                 Kensal Green Backpackers
# 27                               Park Villa
# 28      PubLove @ The Green Man, Paddington
# 29                  Saint James Backpackers
# 30        Le Junction Hostel - Pub & Garden
#
#                                         Distance Ratings Overall Reviews
# 0                Hostel - 1.8km from city centre     8.0        Fabulous
# 1    Hostel - 1.8km from city centre Show on Map     8.0        Fabulous
# 2    Hostel - 1.7km from city centre Show on Map     7.7       Very Good
# 3      Hostel - 3km from city centre Show on Map     7.8       Very Good
# 4    Hostel - 5.4km from city centre Show on Map     9.6          Superb
# 5    Hostel - 4.4km from city centre Show on Map     8.5        Fabulous
# 6   Hostel - 11.9km from city centre Show on Map     8.2        Fabulous
# 7    Hostel - 2.6km from city centre Show on Map     6.8            Good
# 8    Hostel - 2.1km from city centre Show on Map     9.7          Superb
# 9    Hostel - 5.9km from city centre Show on Map     7.6       Very Good
# 10     Hostel - 5km from city centre Show on Map     7.9       Very Good
# 11   Hostel - 1.8km from city centre Show on Map     8.2        Fabulous
# 12   Hostel - 5.7km from city centre Show on Map     7.5       Very Good
# 13   Hostel - 3.6km from city centre Show on Map     8.9        Fabulous
# 14   Hostel - 4.2km from city centre Show on Map     7.9       Very Good
# 15   Hostel - 6.1km from city centre Show on Map     7.1       Very Good
# 16     Hostel - 5km from city centre Show on Map     6.8            Good
# 17   Hostel - 7.5km from city centre Show on Map     8.0        Fabulous
# 18   Hostel - 4.3km from city centre Show on Map     7.7       Very Good
# 19   Hostel - 2.9km from city centre Show on Map     9.0          Superb
# 20     Hostel - 7km from city centre Show on Map     7.7       Very Good
# 21   Hostel - 5.5km from city centre Show on Map     8.1        Fabulous
# 22   Hostel - 7.6km from city centre Show on Map     7.5       Very Good
# 23   Hostel - 5.5km from city centre Show on Map     9.2          Superb
# 24   Hostel - 7.3km from city centre Show on Map     6.5            Good
# 25     Hostel - 5km from city centre Show on Map     8.4        Fabulous
# 26   Hostel - 8.2km from city centre Show on Map     6.1            Good
# 27   Hostel - 6.3km from city centre Show on Map     8.4        Fabulous
# 28   Hostel - 4.3km from city centre Show on Map     7.5       Very Good
# 29   Hostel - 5.5km from city centre Show on Map     6.9            Good
# 30   Hostel - 9.8km from city centre Show on Map     5.9          Rating
